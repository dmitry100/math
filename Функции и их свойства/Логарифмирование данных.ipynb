# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Настройка размеров графика по умолчанию для корректного вывода.
plt.rc('figure', figsize=(12, 8))

# %%
# Считывание данных. В результате data — это NumPy-массив.
data = pd.read_csv('https://code.s3.yandex.net/Math/datasets/sleep.txt', sep='\t')
data = data[['Species', 'BodyWt', 'BrainWt', 'Danger']].dropna().values

# %%
data[:, -1]
# Out:
# array([3, 3, 1, 3, 4, 4, 1, 4, 1, 1, 4, 5, 2, 5, 1, 2, 2, 2, 1, 1, 5, 5,
#        2, 1, 1, 1, 3, 4, 5, 1, 4, 4, 1, 1, 1, 3, 3, 3, 1, 1, 5, 2, 4, 2,
#        4, 5, 2, 3, 1, 2, 2, 3, 5, 5, 2, 2, 2, 3, 2, 4, 1, 1], dtype=object)

# %%
# Настройка размеров графика по умолчанию для корректного вывода.
plt.rc('figure', figsize=(12, 8))

plot = plt.scatter(np.log(data[:, 1].astype('float')), np.log(data[:, 2].astype('float')), c=data[:, 3].astype('float'))

handles, labels = plot.legend_elements()
plt.legend(handles, labels, title='Новый маркетолог')

plt.xlabel('Логарифм массы тела')
plt.ylabel('Логарифм массы мозга')
plt.title('Нужно ли увеличивать мозг?')
plt.show()

# %%
plot = plt.scatter(data[:, 1], data[:, 2], c=data[:, -1])
plt.xscale('log')
plt.yscale('log')

handles, labels = plot.legend_elements()
plt.legend(handles, labels, title='Новый маркетолог')

plt.xlabel('Логарифм массы тела')
plt.ylabel('Логарифм массы мозга')
plt.title('Нужно ли увеличивать мозг?')
plt.show()

# %% [markdown]
# ##### Переход к логарифму по основанию 3

# %%
log3 = np.log(3000) / np.log(3)
result = 60 * 3000 * (log3)

# %% [markdown]
# ##### КР

# %%
vals = pd.read_csv('https://code.s3.yandex.net/Math/datasets/auto-mpg.csv').to_numpy()

# %%
plt.scatter(vals[:, 0], vals[:, 4], c = vals[:, 1])
plt.xscale('log')
plt.yscale('log')

# %%
vals[:, 1]
# Out:
# array([8., 8., 8., 8., 8., 8., 8., 8., 8., 8., 8., 8., 8., 8., 4., 6., 6.,
#        6., 4., 4., 4., 4., 4., 4., 6., 8., 8., 8., 8., 4., 4., 4., 4., 6.,
#        6., 6., 6., 6., 8., 8., 8., 8., 8., 8., 8., 6., 4., 6., 6., 4., 4.,
#        4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 8., 8., 8., 8., 8., 8.,
#        8., 8., 8., 3., 8., 8., 8., 8., 4., 4., 4., 4., 4., 4., 4., 4., 4.,
#        8., 8., 8., 8., 8., 8., 8., 8., 8., 8., 8., 8., 6., 6., 6., 6., 6.,
#        4., 8., 8., 8., 8., 6., 4., 4., 4., 3., 4., 6., 4., 8., 8., 4., 4.,
#        4., 4., 8., 4., 6., 8., 6., 6., 6., 6., 4., 4., 4., 4., 6., 6., 6.,
#        8., 8., 8., 8., 8., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4., 6.,
#        6., 6., 6., 8., 8., 8., 8., 6., 6., 6., 6., 6., 8., 8., 4., 4., 6.,
#        4., 4., 4., 4., 6., 4., 6., 4., 4., 4., 4., 4., 4., 4., 4., 4., 4.,
#        8., 8., 8., 8., 6., 6., 6., 6., 4., 4., 4., 4., 6., 6., 6., 6., 4.,
# ...
